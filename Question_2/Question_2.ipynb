# %%
import re
import requests
import json
from bs4 import BeautifulSoup

# Helper methods for scraping 

def extract_html_script_tag(soup):
    json_script = soup.find('script', type='application/ld+json')
    if json_script:
        try:
            return json.loads(json_script.string)
        except Exception as e:
            print("Error occurred.")
    return {}

def extract_basic_movie_details(movie):

    if movie.get("@type") != "Movie":
        return None
    name = movie.get("name")
    url = movie.get("url")
    rating = movie.get("aggregateRating", {}).get("ratingValue")
    genre = movie.get("genre")
    
    return {
        'title': name,
        'movie_url': url,
        'rating': rating,
        'genre': genre
    }

def extract_release_year(data):
    if "releaseYear" in data:
        return data["releaseYear"].get("year")
    return None

def extract_directors(data):
    directors = []
    if "director" in data:
        directors = [d.get("name") for d in data["director"]]
    return directors

def extract_lead_actors(data):
    lead_actors = []
    if "actor" in data:
        lead_actors = [actor.get("name") for actor in data["actor"]]
    return lead_actors

def is_box_office_tag(tag):
    if tag.name != "span":
        return False
    return "Cumulative Worldwide Gross" in tag.get_text()

def extract_box_office(soup):
    box_office = None
    box_office_html_element = soup.find(is_box_office_tag)
    if box_office_html_element:
        sibling = box_office_html_element.find_next_sibling()
        if sibling:
            box_office = sibling.text.strip()
    return box_office

# %%
HEADERS = {'User-Agent': 'Mozilla/5.0'}

def get_top_250_movie_list():

    top_250_url = "https://www.imdb.com/chart/top/"
    response = requests.get(top_250_url, headers=HEADERS)

    soup = BeautifulSoup(response.text, 'html.parser')
    data = extract_html_script_tag(soup)
    movie_info = []
    
    for element in data.get("itemListElement", []):

        movie = element.get("item", {})
        basic_details = extract_basic_movie_details(movie)

        extra_details = get_extra_movie_details(basic_details.get("movie_url"))
        basic_details.update(extra_details)
        
        movie_info.append(basic_details)

        print(basic_details)
        
    return movie_info

def get_extra_movie_details(movie_url):

    response = requests.get(movie_url, headers=HEADERS)
    soup = BeautifulSoup(response.text, 'html.parser')
    data = extract_html_script_tag(soup)
    details = {}

    details['release_year'] = extract_release_year(data)
    details['directors'] = extract_directors(data)
    details['lead_actors'] = extract_lead_actors(data)
    details['box_office'] = extract_box_office(soup)
    
    return details

print(get_top_250_movie_list())
# Out:
# {'title': 'The Shawshank Redemption', 'description': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'movie_url': 'https://www.imdb.com/title/tt0111161/', 'rating': 9.3, 'year': None, 'genre': 'Drama', 'release_year': None, 'directors': ['Frank Darabont'], 'lead_actors': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'], 'box_office': None}
# {'title': 'The Godfather', 'description': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'movie_url': 'https://www.imdb.com/title/tt0068646/', 'rating': 9.2, 'year': None, 'genre': 'Crime, Drama', 'release_year': None, 'directors': ['Francis Ford Coppola'], 'lead_actors': ['Marlon Brando', 'Al Pacino', 'James Caan'], 'box_office': None}
# {'title': 'The Dark Knight', 'description': 'When a menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman, James Gordon and Harvey Dent must work together to put an end to the madness.', 'movie_url': 'https://www.imdb.com/title/tt0468569/', 'rating': 9, 'year': None, 'genre': 'Action, Crime, Drama', 'release_year': None, 'directors': ['Christopher Nolan'], 'lead_actors': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart'], 'box_office': None}
# {'title': 'The Godfather Part II', 'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'movie_url': 'https://www.imdb.com/title/tt0071562/', 'rating': 9, 'year': None, 'genre': 'Crime, Drama', 'release_year': None, 'directors': ['Francis Ford Coppola'], 'lead_actors': ['Al Pacino', 'Robert De Niro', 'Robert Duvall'], 'box_office': None}
# {'title': '12 Angry Men', 'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'movie_url': 'https://www.imdb.com/title/tt0050083/', 'rating': 9, 'year': None, 'genre': 'Crime, Drama', 'release_year': None, 'directors': ['Sidney Lumet'], 'lead_actors': ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'], 'box_office': None}
# {'title': 'The Lord of the Rings: The Return of the King', 'description': 'Gandalf and Aragorn lead the World of Men against Sauron&apos;s army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.', 'movie_url': 'https://www.imdb.com/title/tt0167260/', 'rating': 9, 'year': None, 'genre': 'Adventure, Drama, Fantasy', 'release_year': None, 'directors': ['Peter Jackson'], 'lead_actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'box_office': None}
# {'title': 'Schindler&apos;s List', 'description': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.', 'movie_url': 'https://www.imdb.com/title/tt0108052/', 'rating': 9, 'year': None, 'genre': 'Biography, Drama, History', 'release_year': None, 'directors': ['Steven Spielberg'], 'lead_actors': ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley'], 'box_office': None}
# {'title': 'Pulp Fiction', 'description': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.', 'movie_url': 'https://www.imdb.com/title/tt0110912/', 'rating': 8.9, 'year': None, 'genre': 'Crime, Drama', 'release_year': None, 'directors': ['Quentin Tarantino'], 'lead_actors': ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson'], 'box_office': None}
# {'title': 'The Lord of the Rings: The Fellowship of the Ring', 'description': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.', 'movie_url': 'https://www.imdb.com/title/tt0120737/', 'rating': 8.9, 'year': None, 'genre': 'Adventure, Drama, Fantasy', 'release_year': None, 'directors': ['Peter Jackson'], 'lead_actors': ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom'], 'box_office': None}
# {'title': 'Il buono, il brutto, il cattivo', 'description': 'A bounty-hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.', 'movie_url': 'https://www.imdb.com/title/tt0060196/', 'rating': 8.8, 'year': None, 'genre': 'Adventure, Western', 'release_year': None, 'directors': ['Sergio Leone'], 'lead_actors': ['Clint Eastwood', 'Eli Wallach', 'Lee Van Cleef'], 'box_office': None}
# {'title': 'Forrest Gump', 'description': 'The history of the United States from the 1950s to the &apos;70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.', 'movie_url': 'https://www.imdb.com/title/tt0109830/', 'rating': 8.8, 'year': None, 'genre': 'Drama, Romance', 'release_year': None, 'directors': ['Robert Zemeckis'], 'lead_actors': ['Tom Hanks', 'Robin Wright', 'Gary Sinise'], 'box_office': None}
# {'title': 'The Lord of the Rings: The Two Towers', 'description': 'While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron&apos;s new ally, Saruman, and his hordes of Isengard.', 'movie_url': 'https://www.imdb.com/title/tt0167261/', 'rating': 8.8, 'year': None, 'genre': 'Adventure, Drama, Fantasy', 'release_year': None, 'directors': ['Peter Jackson'], 'lead_actors': ['Elijah Wood', 'Ian McKellen', 'Viggo Mortensen'], 'box_office': None}
# {'title': 'Fight Club', 'description': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.', 'movie_url': 'https://www.imdb.com/title/tt0137523/', 'rating': 8.8, 'year': None, 'genre': 'Drama', 'release_year': None, 'directors': ['David Fincher'], 'lead_actors': ['Brad Pitt', 'Edward Norton', 'Meat Loaf'], 'box_office': None}
# {'title': 'Inception', 'description': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.', 'movie_url': 'https://www.imdb.com/title/tt1375666/', 'rating': 8.8, 'year': None, 'genre': 'Action, Adventure, Sci-Fi', 'release_year': None, 'directors': ['Christopher Nolan'], 'lead_actors': ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page'], 'box_office': None}
# {'title': 'Star Wars: Episode V - The Empire Strikes Back', 'description': 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy.', 'movie_url': 'https://www.imdb.com/title/tt0080684/', 'rating': 8.7, 'year': None, 'genre': 'Action, Adventure, Fantasy', 'release_year': None, 'directors': ['Irvin Kershner'], 'lead_actors': ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher'], 'box_office': None}
# {'title': 'The Matrix', 'description': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'movie_url': 'https://www.imdb.com/title/tt0133093/', 'rating': 8.7, 'year': None, 'genre': 'Action, Sci-Fi', 'release_year': None, 'directors': ['Lana Wachowski', 'Lilly Wachowski'], 'lead_actors': ['Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss'], 'box_office': None}
# {'title': 'GoodFellas', 'description': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.', 'movie_url': 'https://www.imdb.com/title/tt0099685/', 'rating': 8.7, 'year': None, 'genre': 'Biography, Crime, Drama', 'release_year': None, 'directors': ['Martin Scorsese'], 'lead_actors': ['Robert De Niro', 'Ray Liotta', 'Joe Pesci'], 'box_office': None}
# {'title': 'One Flew Over the Cuckoo&apos;s Nest', 'description': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.', 'movie_url': 'https://www.imdb.com/title/tt0073486/', 'rating': 8.7, 'year': None, 'genre': 'Drama', 'release_year': None, 'directors': ['Milos Forman'], 'lead_actors': ['Jack Nicholson', 'Louise Fletcher', 'Michael Berryman'], 'box_office': None}
# {'title': 'Interstellar', 'description': 'When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.', 'movie_url': 'https://www.imdb.com/title/tt0816692/', 'rating': 8.7, 'year': None, 'genre': 'Adventure, Drama, Sci-Fi', 'release_year': None, 'directors': ['Christopher Nolan'], 'lead_actors': ['Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain'], 'box_office': None}
# {'title': 'Se7en', 'description': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.', 'movie_url': 'https://www.imdb.com/title/tt0114369/', 'rating': 8.6, 'year': None, 'genre': 'Crime, Drama, Mystery', 'release_year': None, 'directors': ['David Fincher'], 'lead_actors': ['Morgan Freeman', 'Brad Pitt', 'Kevin Spacey'], 'box_office': None}
# {'title': 'It&apos;s a Wonderful Life', 'description': 'An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.', 'movie_url': 'https://www.imdb.com/title/tt0038650/', 'rating': 8.6, 'year': None, 'genre': 'Drama, Family, Fantasy', 'release_year': None, 'directors': ['Frank Capra'], 'lead_actors': ['James Stewart', 'Donna Reed', 'Lionel Barrymore'], 'box_office': None}
# {'title': 'Shichinin no samurai', 'description': 'Farmers from a village exploited by bandits hire a veteran samurai for protection, and he gathers six other samurai to join him.', 'movie_url': 'https://www.imdb.com/title/tt0047478/', 'rating': 8.6, 'year': None, 'genre': 'Action, Drama', 'release_year': None, 'directors': ['Akira Kurosawa'], 'lead_actors': ['Toshirô Mifune', 'Takashi Shimura', 'Keiko Tsushima'], 'box_office': None}
# {'title': 'The Silence of the Lambs', 'description': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'movie_url': 'https://www.imdb.com/title/tt0102926/', 'rating': 8.6, 'year': None, 'genre': 'Crime, Drama, Horror', 'release_year': None, 'directors': ['Jonathan Demme'], 'lead_actors': ['Jodie Foster', 'Anthony Hopkins', 'Scott Glenn'], 'box_office': None}
# {'title': 'Saving Private Ryan', 'description': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'movie_url': 'https://www.imdb.com/title/tt0120815/', 'rating': 8.6, 'year': None, 'genre': 'Drama, War', 'release_year': None, 'directors': ['Steven Spielberg'], 'lead_actors': ['Tom Hanks', 'Matt Damon', 'Tom Sizemore'], 'box_office': None}
# {'title': 'Cidade de Deus', 'description': 'In the slums of Rio, two kids&apos; paths diverge as one struggles to become a photographer and the other a kingpin.', 'movie_url': 'https://www.imdb.com/title/tt0317248/', 'rating': 8.6, 'year': None, 'genre': 'Crime, Drama', 'release_year': None, 'directors': ['Fernando Meirelles', 'Kátia Lund'], 'lead_actors': ['Alexandre Rodrigues', 'Leandro Firmino', 'Matheus Nachtergaele'], 'box_office': None}
# {'title': 'The Green Mile', 'description': 'A death row guard learns that a gentle giant in his charge possesses a mysterious gift.', 'movie_url': 'https://www.imdb.com/title/tt0120689/', 'rating': 8.6, 'year': None, 'genre': 'Crime, Drama, Fantasy', 'release_year': None, 'directors': ['Frank Darabont'], 'lead_actors': ['Tom Hanks', 'Michael Clarke Duncan', 'David Morse'], 'box_office': None}
# {'title': 'La vita è bella', 'description': 'When an open-minded Jewish waiter and his son become victims of the Holocaust, he uses a perfect mixture of will, humor and imagination to protect his son from the dangers around their camp.', 'movie_url': 'https://www.imdb.com/title/tt0118799/', 'rating': 8.6, 'year': None, 'genre': 'Comedy, Drama, Romance', 'release_year': None, 'directors': ['Roberto Benigni'], 'lead_actors': ['Roberto Benigni', 'Nicoletta Braschi', 'Giorgio Cantarini'], 'box_office': None}
# {'title': 'Terminator 2: Judgment Day', 'description': 'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten year old son John from an even more advanced and powerful cyborg.', 'movie_url': 'https://www.imdb.com/title/tt0103064/', 'rating': 8.6, 'year': None, 'genre': 'Action, Adventure, Sci-Fi', 'release_year': None, 'directors': ['James Cameron'], 'lead_actors': ['Arnold Schwarzenegger', 'Linda Hamilton', 'Edward Furlong'], 'box_office': None}
# {'title': 'Star Wars', 'description': 'Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire&apos;s world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth ...', 'movie_url': 'https://www.imdb.com/title/tt0076759/', 'rating': 8.6, 'year': None, 'genre': 'Action, Adventure, Fantasy', 'release_year': None, 'directors': ['George Lucas'], 'lead_actors': ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher'], 'box_office': None}
# {'title': 'Back to the Future', 'description': 'Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.', 'movie_url': 'https://www.imdb.com/title/tt0088763/', 'rating': 8.5, 'year': None, 'genre': 'Adventure, Comedy, Sci-Fi', 'release_year': None, 'directors': ['Robert Zemeckis'], 'lead_actors': ['Michael J. Fox', 'Christopher Lloyd', 'Lea Thompson'], 'box_office': None}
# {'title': 'Sen to Chihiro no kamikakushi', 'description': 'During her family&apos;s move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches and spirits, and where humans are changed into beasts.', 'movie_url': 'https://www.imdb.com/title/tt0245429/', 'rating': 8.6, 'year': None, 'genre': 'Animation, Adventure, Family', 'release_year': None, 'directors': ['Hayao Miyazaki'], 'lead_actors': ['Daveigh Chase', 'Suzanne Pleshette', 'Miyu Irino'], 'box_office': None}
# {'title': 'The Pianist', 'description': 'During WWII, acclaimed Polish musician Wladyslaw faces various struggles as he loses contact with his family. As the situation worsens, he hides in the ruins of Warsaw in order to survive.', 'movie_url': 'https://www.imdb.com/title/tt0253474/', 'rating': 8.5, 'year': None, 'genre': 'Biography, Drama, Music', 'release_year': None, 'directors': ['Roman Polanski'], 'lead_actors': ['Adrien Brody', 'Thomas Kretschmann', 'Frank Finlay'], 'box_office': None}
# {'title': 'Gladiator', 'description': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.', 'movie_url': 'https://www.imdb.com/title/tt0172495/', 'rating': 8.5, 'year': None, 'genre': 'Action, Adventure, Drama', 'release_year': None, 'directors': ['Ridley Scott'], 'lead_actors': ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen'], 'box_office': None}
# {'title': 'Gisaengchung', 'description': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.', 'movie_url': 'https://www.imdb.com/title/tt6751668/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Thriller', 'release_year': None, 'directors': ['Bong Joon Ho'], 'lead_actors': ['Song Kang-ho', 'Lee Sun-kyun', 'Cho Yeo-jeong'], 'box_office': None}
# {'title': 'Psycho', 'description': 'A secretary on the run for embezzlement takes refuge at a secluded California motel owned by a repressed man and his overbearing mother.', 'movie_url': 'https://www.imdb.com/title/tt0054215/', 'rating': 8.5, 'year': None, 'genre': 'Horror, Mystery, Thriller', 'release_year': None, 'directors': ['Alfred Hitchcock'], 'lead_actors': ['Anthony Perkins', 'Janet Leigh', 'Vera Miles'], 'box_office': None}
# {'title': 'The Lion King', 'description': 'Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.', 'movie_url': 'https://www.imdb.com/title/tt0110357/', 'rating': 8.5, 'year': None, 'genre': 'Animation, Adventure, Drama', 'release_year': None, 'directors': ['Roger Allers', 'Rob Minkoff'], 'lead_actors': ['Matthew Broderick', 'Jeremy Irons', 'James Earl Jones'], 'box_office': None}
# {'title': 'Hotaru no haka', 'description': 'A young boy and his little sister struggle to survive in Japan during World War II.', 'movie_url': 'https://www.imdb.com/title/tt0095327/', 'rating': 8.5, 'year': None, 'genre': 'Animation, Drama, War', 'release_year': None, 'directors': ['Isao Takahata'], 'lead_actors': ['Tsutomu Tatsumi', 'Ayano Shiraishi', 'Akemi Yamaguchi'], 'box_office': None}
# {'title': 'The Departed', 'description': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.', 'movie_url': 'https://www.imdb.com/title/tt0407887/', 'rating': 8.5, 'year': None, 'genre': 'Crime, Drama, Thriller', 'release_year': None, 'directors': ['Martin Scorsese'], 'lead_actors': ['Leonardo DiCaprio', 'Matt Damon', 'Jack Nicholson'], 'box_office': None}
# {'title': 'Whiplash', 'description': 'A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student&apos;s potential.', 'movie_url': 'https://www.imdb.com/title/tt2582802/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Music', 'release_year': None, 'directors': ['Damien Chazelle'], 'lead_actors': ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist'], 'box_office': None}
# {'title': 'Seppuku', 'description': 'When a ronin requesting seppuku at a feudal lord&apos;s palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan&apos;s integrity.', 'movie_url': 'https://www.imdb.com/title/tt0056058/', 'rating': 8.6, 'year': None, 'genre': 'Drama, Mystery', 'release_year': None, 'directors': ['Masaki Kobayashi'], 'lead_actors': ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima Iwashita'], 'box_office': None}
# {'title': 'American History X', 'description': 'Living a life marked by violence, neo-Nazi Derek finally goes to prison after killing two black youths. Upon his release, Derek vows to change; he hopes to prevent his brother, Danny, who idolizes Derek, from following in his foot...', 'movie_url': 'https://www.imdb.com/title/tt0120586/', 'rating': 8.5, 'year': None, 'genre': 'Crime, Drama', 'release_year': None, 'directors': ['Tony Kaye'], 'lead_actors': ['Edward Norton', 'Edward Furlong', 'Beverly D&apos;Angelo'], 'box_office': None}
# {'title': 'The Prestige', 'description': 'Rival 19th-century magicians engage in a bitter battle for trade secrets.', 'movie_url': 'https://www.imdb.com/title/tt0482571/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Mystery, Sci-Fi', 'release_year': None, 'directors': ['Christopher Nolan'], 'lead_actors': ['Christian Bale', 'Hugh Jackman', 'Scarlett Johansson'], 'box_office': None}
# {'title': 'Léon', 'description': '12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin&apos;s trade.', 'movie_url': 'https://www.imdb.com/title/tt0110413/', 'rating': 8.5, 'year': None, 'genre': 'Action, Crime, Drama', 'release_year': None, 'directors': ['Luc Besson'], 'lead_actors': ['Jean Reno', 'Gary Oldman', 'Natalie Portman'], 'box_office': None}
# {'title': 'Spider-Man: Across the Spider-Verse', 'description': 'Traveling across the multiverse, Miles Morales meets a new team of Spider-People, made up of heroes from different dimensions. But when the heroes clash over how to deal with a new threat, Miles finds himself at a crossroads.', 'movie_url': 'https://www.imdb.com/title/tt9362722/', 'rating': 8.5, 'year': None, 'genre': 'Animation, Action, Adventure', 'release_year': None, 'directors': ['Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson'], 'lead_actors': ['Shameik Moore', 'Hailee Steinfeld', 'Brian Tyree Henry'], 'box_office': None}
# {'title': 'Casablanca', 'description': 'A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.', 'movie_url': 'https://www.imdb.com/title/tt0034583/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Romance, War', 'release_year': None, 'directors': ['Michael Curtiz'], 'lead_actors': ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid'], 'box_office': None}
# {'title': 'The Usual Suspects', 'description': 'The sole survivor of a pier shoot-out tells the story of how a notorious criminal influenced the events that began with five criminals meeting in a seemingly random police lineup.', 'movie_url': 'https://www.imdb.com/title/tt0114814/', 'rating': 8.5, 'year': None, 'genre': 'Crime, Drama, Mystery', 'release_year': None, 'directors': ['Bryan Singer'], 'lead_actors': ['Kevin Spacey', 'Gabriel Byrne', 'Chazz Palminteri'], 'box_office': None}
# {'title': 'Intouchables', 'description': 'After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.', 'movie_url': 'https://www.imdb.com/title/tt1675434/', 'rating': 8.5, 'year': None, 'genre': 'Comedy, Drama', 'release_year': None, 'directors': ['Olivier Nakache', 'Éric Toledano'], 'lead_actors': ['François Cluzet', 'Omar Sy', 'Anne Le Ny'], 'box_office': None}
# {'title': 'Nuovo Cinema Paradiso', 'description': 'Salvatore, a famous film director, returns to his hometown for the funeral of the local theater&apos;s film projectionist, Alfredo. He reminisces about his life as a young boy falling in love with cinema.', 'movie_url': 'https://www.imdb.com/title/tt0095765/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Romance', 'release_year': None, 'directors': ['Giuseppe Tornatore'], 'lead_actors': ['Philippe Noiret', 'Enzo Cannavale', 'Antonella Attili'], 'box_office': None}
# {'title': 'Modern Times', 'description': 'The Tramp struggles to live in modern industrial society with the help of a young homeless woman.', 'movie_url': 'https://www.imdb.com/title/tt0027977/', 'rating': 8.5, 'year': None, 'genre': 'Comedy, Drama, Romance', 'release_year': None, 'directors': ['Charles Chaplin'], 'lead_actors': ['Charles Chaplin', 'Paulette Goddard', 'Henry Bergman'], 'box_office': None}
# {'title': 'Alien', 'description': 'After investigating a mysterious transmission of unknown origin, the crew of a commercial spacecraft encounters a deadly lifeform.', 'movie_url': 'https://www.imdb.com/title/tt0078748/', 'rating': 8.5, 'year': None, 'genre': 'Horror, Sci-Fi', 'release_year': None, 'directors': ['Ridley Scott'], 'lead_actors': ['Sigourney Weaver', 'Tom Skerritt', 'John Hurt'], 'box_office': None}
# {'title': 'Rear Window', 'description': 'A bored photographer recovering from a broken leg passes the time by watching his neighbors and begins to suspect one of them of murder.', 'movie_url': 'https://www.imdb.com/title/tt0047396/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Mystery, Thriller', 'release_year': None, 'directors': ['Alfred Hitchcock'], 'lead_actors': ['James Stewart', 'Grace Kelly', 'Wendell Corey'], 'box_office': None}
# {'title': 'C&apos;era una volta il West', 'description': 'A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.', 'movie_url': 'https://www.imdb.com/title/tt0064116/', 'rating': 8.5, 'year': None, 'genre': 'Drama, Western', 'release_year': None, 'directors': ['Sergio Leone'], 'lead_actors': ['Henry Fonda', 'Charles Bronson', 'Claudia Cardinale'], 'box_office': None}
# {'title': 'Django Unchained', 'description': 'With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation owner in Mississippi.', 'movie_url': 'https://www.imdb.com/title/tt1853728/', 'rating': 8.5, 'year': None, 'genre': 'Western', 'release_year': None, 'directors': ['Quentin Tarantino'], 'lead_actors': ['Jamie Foxx', 'Christoph Waltz', 'Leonardo DiCaprio'], 'box_office': None}
# {'title': 'City Lights', 'description': 'With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically.', 'movie_url': 'https://www.imdb.com/title/tt0021749/', 'rating': 8.5, 'year': None, 'genre': 'Comedy, Drama, Romance', 'release_year': None, 'directors': ['Charles Chaplin'], 'lead_actors': ['Charles Chaplin', 'Virginia Cherrill', 'Florence Lee'], 'box_office': None}
# {'title': 'Apocalypse Now', 'description': 'A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.', 'movie_url': 'https://www.imdb.com/title/tt0078788/', 'rating': 8.4, 'year': None, 'genre': 'Drama, Mystery, War', 'release_year': None, 'directors': ['Francis Ford Coppola'], 'lead_actors': ['Martin Sheen', 'Marlon Brando', 'Robert Duvall'], 'box_office': None}
# {'title': 'Dune: Part Two', 'description': 'Paul Atreides unites with the Fremen while on a warpath of revenge against the conspirators who destroyed his family. Facing a choice between the love of his life and the fate of the universe, he endeavors to prevent a terrible fu...', 'movie_url': 'https://www.imdb.com/title/tt15239678/', 'rating': 8.5, 'year': None, 'genre': 'Action, Adventure, Drama', 'release_year': None, 'directors': ['Denis Villeneuve'], 'lead_actors': ['Timothée Chalamet', 'Zendaya', 'Rebecca Ferguson'], 'box_office': None}
# {'title': 'Memento', 'description': 'Leonard Shelby, an insurance investigator, suffers from anterograde amnesia and uses notes and tattoos to hunt for the man he thinks killed his wife, which is the last thing he remembers.', 'movie_url': 'https://www.imdb.com/title/tt0209144/', 'rating': 8.4, 'year': None, 'genre': 'Mystery, Thriller', 'release_year': None, 'directors': ['Christopher Nolan'], 'lead_actors': ['Guy Pearce', 'Carrie-Anne Moss', 'Joe Pantoliano'], 'box_office': None}
# {'title': 'WALL·E', 'description': 'A robot who is responsible for cleaning a waste-covered Earth meets another robot and falls in love with her. Together, they set out on a journey that will alter the fate of mankind.', 'movie_url': 'https://www.imdb.com/title/tt0910970/', 'rating': 8.4, 'year': None, 'genre': 'Animation, Adventure, Family', 'release_year': None, 'directors': ['Andrew Stanton'], 'lead_actors': ['Ben Burtt', 'Elissa Knight', 'Jeff Garlin'], 'box_office': None}
# {'title': 'Raiders of the Lost Ark', 'description': 'In 1936, archaeologists and adventurers of the U.S. government hired Indiana Jones to find the Ark of the Covenant before the Nazis could obtain its extraordinary powers.', 'movie_url': 'https://www.imdb.com/title/tt0082971/', 'rating': 8.4, 'year': None, 'genre': 'Action, Adventure', 'release_year': None, 'directors': ['Steven Spielberg'], 'lead_actors': ['Harrison Ford', 'Karen Allen', 'Paul Freeman'], 'box_office': None}
# {'title': 'Das Leben der Anderen', 'description': 'In 1984 East Berlin, an agent of the secret police conducting surveillance on a writer and his lover finds himself becoming increasingly absorbed by their lives.', 'movie_url': 'https://www.imdb.com/title/tt0405094/', 'rating': 8.4, 'year': None, 'genre': 'Drama, Mystery, Thriller', 'release_year': None, 'directors': ['Florian Henckel von Donnersmarck'], 'lead_actors': ['Ulrich Mühe', 'Martina Gedeck', 'Sebastian Koch'], 'box_office': None}
# {'title': 'Avengers: Infinity War', 'description': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.', 'movie_url': 'https://www.imdb.com/title/tt4154756/', 'rating': 8.4, 'year': None, 'genre': 'Action, Adventure, Sci-Fi', 'release_year': None, 'directors': ['Anthony Russo', 'Joe Russo'], 'lead_actors': ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo'], 'box_office': None}
# {'title': 'Sunset Boulevard', 'description': 'A screenwriter develops a dangerous relationship with a faded film star determined to make a triumphant return.', 'movie_url': 'https://www.imdb.com/title/tt0043014/', 'rating': 8.4, 'year': None, 'genre': 'Drama, Film-Noir', 'release_year': None, 'directors': ['Billy Wilder'], 'lead_actors': ['William Holden', 'Gloria Swanson', 'Erich von Stroheim'], 'box_office': None}
# {'title': 'Spider-Man: Into the Spider-Verse', 'description': 'Teen Miles Morales becomes the Spider-Man of his universe and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.', 'movie_url': 'https://www.imdb.com/title/tt4633694/', 'rating': 8.4, 'year': None, 'genre': 'Animation, Action, Adventure', 'release_year': None, 'directors': ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman'], 'lead_actors': ['Shameik Moore', 'Jake Johnson', 'Hailee Steinfeld'], 'box_office': None}
# {'title': 'Paths of Glory', 'description': 'A colonel defends three of his soldiers in a court-martial after they abandon a suicidal attack.', 'movie_url': 'https://www.imdb.com/title/tt0050825/', 'rating': 8.4, 'year': None, 'genre': 'Drama, War', 'release_year': None, 'directors': ['Stanley Kubrick'], 'lead_actors': ['Kirk Douglas', 'Ralph Meeker', 'Adolphe Menjou'], 'box_office': None}
# {'title': 'Witness for the Prosecution', 'description': 'A veteran British barrister must defend his client in a murder trial that has surprise after surprise.', 'movie_url': 'https://www.imdb.com/title/tt0051201/', 'rating': 8.4, 'year': None, 'genre': 'Crime, Drama, Mystery', 'release_year': None, 'directors': ['Billy Wilder'], 'lead_actors': ['Tyrone Power', 'Marlene Dietrich', 'Charles Laughton'], 'box_office': None}
# {'title': 'The Shining', 'description': 'A family heads to an isolated hotel for the winter, where a sinister presence influences the father into violence. At the same time, his psychic son sees horrifying forebodings from both the past and the future.', 'movie_url': 'https://www.imdb.com/title/tt0081505/', 'rating': 8.4, 'year': None, 'genre': 'Drama, Horror', 'release_year': None, 'directors': ['Stanley Kubrick'], 'lead_actors': ['Jack Nicholson', 'Shelley Duvall', 'Danny Lloyd'], 'box_office': None}
# {'title': 'The Great Dictator', 'description': 'Dictator Adenoid Hynkel tries to expand his empire while a poor Jewish barber tries to avoid persecution from Hynkel&apos;s regime.', 'movie_url': 'https://www.imdb.com/title/tt0032553/', 'rating': 8.4, 'year': None, 'genre': 'Comedy, Drama, War', 'release_year': None, 'directors': ['Charles Chaplin'], 'lead_actors': ['Charles Chaplin', 'Paulette Goddard', 'Jack Oakie'], 'box_office': None}
# {'title': '12th Fail', 'description': 'The real-life story of IPS Officer Manoj Kumar Sharma and IRS Officer Shraddha Joshi.', 'movie_url': 'https://www.imdb.com/title/tt23849204/', 'rating': 8.8, 'year': None, 'genre': 'Biography, Drama', 'release_year': None, 'directors': ['Vidhu Vinod Chopra'], 'lead_actors': ['Vikrant Massey', 'Medha Shankr', 'Anant Joshi'], 'box_office': None}
# {'title': 'Aliens', 'description': 'Decades after surviving the Nostromo incident, Ellen Ripley is sent out to re-establish contact with a terraforming colony but finds herself battling the Alien Queen and her offspring.', 'movie_url': 'https://www.imdb.com/title/tt0090605/', 'rating': 8.4, 'year': None, 'genre': 'Action, Adventure, Horror', 'release_year': None, 'directors': ['James Cameron'], 'lead_actors': ['Sigourney Weaver', 'Michael Biehn', 'Carrie Henn'], 'box_office': None}
# {'title': 'Inglourious Basterds', 'description': 'In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner&apos;s vengeful plans for the same.', 'movie_url': 'https://www.imdb.com/title/tt0361748/', 'rating': 8.4, 'year': None, 'genre': 'Adventure, Drama, War', 'release_year': None, 'directors': ['Quentin Tarantino'], 'lead_actors': ['Brad Pitt', 'Diane Kruger', 'Eli Roth'], 'box_office': None}
# {'title': 'The Dark Knight Rises', 'description': 'Bane, an imposing terrorist, attacks Gotham City and disrupts its eight-year-long period of peace. This forces Bruce Wayne to come out of hiding and don the cape and cowl of Batman again.', 'movie_url': 'https://www.imdb.com/title/tt1345836/', 'rating': 8.4, 'year': None, 'genre': 'Action, Drama, Thriller', 'release_year': None, 'directors': ['Christopher Nolan'], 'lead_actors': ['Christian Bale', 'Tom Hardy', 'Anne Hathaway'], 'box_office': None}
# {'title': 'Coco', 'description': 'Aspiring musician Miguel, confronted with his family&apos;s ancestral ban on music, enters the Land of the Dead to find his great-great-grandfather, a legendary singer.', 'movie_url': 'https://www.imdb.com/title/tt2380307/', 'rating': 8.4, 'year': None, 'genre': 'Animation, Adventure, Drama', 'release_year': None, 'directors': ['Lee Unkrich', 'Adrian Molina'], 'lead_actors': ['Anthony Gonzalez', 'Gael García Bernal', 'Benjamin Bratt'], 'box_office': None}
# {'title': 'Amadeus', 'description': 'The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporaneous composer who was deeply jealous of Mozart&apos;s talent and claimed to have murdered him.', 'movie_url': 'https://www.imdb.com/title/tt0086879/', 'rating': 8.4, 'year': None, 'genre': 'Biography, Drama, Music', 'release_year': None, 'directors': ['Milos Forman'], 'lead_actors': ['F. Murray Abraham', 'Tom Hulce', 'Elizabeth Berridge'], 'box_office': None}
# {'title': 'Toy Story', 'description': 'A cowboy doll is profoundly threatened and jealous when a new spaceman action figure supplants him as top toy in a boy&apos;s bedroom.', 'movie_url': 'https://www.imdb.com/title/tt0114709/', 'rating': 8.3, 'year': None, 'genre': 'Animation, Adventure, Comedy', 'release_year': None, 'directors': ['John Lasseter'], 'lead_actors': ['Tom Hanks', 'Tim Allen', 'Don Rickles'], 'box_office': None}
# {'title': 'Avengers: Endgame', 'description': 'After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos&apos; actions and restore balance to the universe.', 'movie_url': 'https://www.imdb.com/title/tt4154796/', 'rating': 8.4, 'year': None, 'genre': 'Action, Adventure, Sci-Fi', 'release_year': None, 'directors': ['Anthony Russo', 'Joe Russo'], 'lead_actors': ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo'], 'box_office': None}
# {'title': 'Good Will Hunting', 'description': 'Will Hunting, a janitor at MIT, has a gift for mathematics, but needs help from a psychologist to find direction in his life.', 'movie_url': 'https://www.imdb.com/title/tt0119217/', 'rating': 8.3, 'year': None, 'genre': 'Drama, Romance', 'release_year': None, 'directors': ['Gus Van Sant'], 'lead_actors': ['Robin Williams', 'Matt Damon', 'Ben Affleck'], 'box_office': None}
# {'title': 'Oldeuboi', 'description': 'After being kidnapped and imprisoned for fifteen years, Oh Dae-Su is released, only to find that he must track down his captor in five days.', 'movie_url': 'https://www.imdb.com/title/tt0364569/', 'rating': 8.3, 'year': None, 'genre': 'Action, Drama, Mystery', 'release_year': None, 'directors': ['Park Chan-wook'], 'lead_actors': ['Choi Min-sik', 'Yoo Ji-tae', 'Kang Hye-jeong'], 'box_office': None}
