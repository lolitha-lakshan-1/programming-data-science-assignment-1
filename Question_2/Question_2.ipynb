# %%
import requests
import json
from bs4 import BeautifulSoup

HEADERS = {'User-Agent': 'Mozilla/5.0'}

def get_top_250_movie_list():

    top_250_url = 'https://www.imdb.com/chart/top'
    response = requests.get(top_250_url, headers=HEADERS)
    soup = BeautifulSoup(response.text, 'html.parser')

    movie_info = []

    #Currently first script contains movie info
    json_scripts = soup.find('script', type='application/ld+json')
    for script in json_scripts:
        try:
         data = json.loads(script.string)
        # Process the JSON data as needed
        except Exception as e:
         print("Error processing script:", e)

    for element in data["itemListElement"]:
     movie = element["item"]
     # Validate that the type is "Movie"
     if movie.get("@type") != "Movie":
        continue

     name = movie.get("name")
     description = movie.get("description")
     url = movie.get("url")
     rating = movie.get("aggregateRating", {}).get("ratingValue")
     year = movie.get("releaseYear", {}).get("year")
     genre = movie.get("genre")
     
     movie_info.append({
            'title': name,
            'year': year,
            'rating': rating,
            'movie_url': url,
            'genre' : genre
        })
     
     print(f"Name: {name}")
     print(f"Description: {description}")
     print(f"URL: {url}\n")
     print(f"Rating: {rating}")
     print(f"Genre: {genre}\n")

    return movie_info

print(get_top_250_movie_list())
# Out:
# Name: The Shawshank Redemption
# Description: A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.
# URL: https://www.imdb.com/title/tt0111161/
#
# Rating: 9.3
# Genre: Drama
#
# Name: The Godfather
# Description: The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.
# URL: https://www.imdb.com/title/tt0068646/
#
# Rating: 9.2
# Genre: Crime, Drama
#
# Name: The Dark Knight
# Description: When a menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman, James Gordon and Harvey Dent must work together to put an end to the madness.
# URL: https://www.imdb.com/title/tt0468569/
#
# Rating: 9
# Genre: Action, Crime, Drama
#
# Name: The Godfather Part II
# ...
